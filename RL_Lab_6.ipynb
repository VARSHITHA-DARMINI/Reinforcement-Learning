# %% [markdown]
# <a href="https://colab.research.google.com/github/VARSHITHA-DARMINI/Reinforcement-Learning/blob/main/RL_Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# REINFORCEMENT LEARNING - ASSIGNMENT 6
# Building a Random Agent for Reinforcement Learning Environments
# Environments: CliffWalking and Taxi

# !pip install -q gymnasium

import gymnasium as gym
import numpy as np

NUM_EPISODES = 5


def random_agent(env_name):

    print("\n" + "=" * 60)
    print("Environment:", env_name)
    print("=" * 60)

    # Create environment
    env = gym.make(env_name)

    rewards = []

    for episode in range(1, NUM_EPISODES + 1):

        # Reset environment
        state, info = env.reset()

        total_reward = 0
        steps = 0

        while True:

            # Select random action
            action = env.action_space.sample()

            # Execute action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Observe next state and reward
            state = next_state
            total_reward += reward
            steps += 1

            # Check whether episode has terminated
            if terminated or truncated:
                break

        rewards.append(total_reward)

        # Display result for each episode
        print(f"Episode {episode}: Total Reward = {total_reward}")
        print(f"Steps = {steps}")

    # Calculate average reward
    average_reward = np.mean(rewards)

    print("\nTotal Rewards:", rewards)
    print("Average Reward:", round(average_reward, 2))

    env.close()


# --------------------------------------------------
# 1. CLIFF WALKING
# --------------------------------------------------
random_agent("CliffWalking-v1")


# --------------------------------------------------
# 2. TAXI
# --------------------------------------------------
random_agent("Taxi-v4")
# Out:
# ...
# Environment: CliffWalking-v1
# ...
# Episode 1: Total Reward = -17821
# Steps = 2080
# Episode 2: Total Reward = -50207
# Steps = 5063
# Episode 3: Total Reward = -6653
# Steps = 812
# Episode 4: Total Reward = -50547
# Steps = 4809
# Episode 5: Total Reward = -24430
# Steps = 2353
#
# Total Rewards: [-17821, -50207, -6653, -50547, -24430]
# Average Reward: -29931.6
#
# ...
# Environment: Taxi-v4
# ...
# Episode 1: Total Reward = -866
# Steps = 200
# Episode 2: Total Reward = -785
# Steps = 200
# Episode 3: Total Reward = -373
# Steps = 106
# Episode 4: Total Reward = -767
# Steps = 200
# Episode 5: Total Reward = -812
# Steps = 200
#
# Total Rewards: [-866, -785, -373, -767, -812]
# Average Reward: -720.6
